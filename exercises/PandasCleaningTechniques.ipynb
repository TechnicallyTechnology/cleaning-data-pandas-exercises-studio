# %% [markdown]
# # Cleaning Data with Pandas Exercises
#
# For the exercises, you will be cleaning data in the Women's Clothing E-Commerce Reviews dataset.
#
# **Dataset Information:**
# - **Dataset Name:** Women's Clothing E-Commerce Reviews
# - **File:** `Womens Clothing E-Commerce Reviews.csv`
# - **Source:** This dataset contains reviews written by customers and includes features like ratings, review text, product categories, and customer information.
#
# To start cleaning data, we first need to create a dataframe from the CSV and print out any relevant info to make sure our dataframe is ready to go.

# %%
# Import pandas and any other libraries you need here.
import pandas as pd


# Create a new dataframe from your CSV
df = pd.read_csv("Womens Clothing E-Commerce Reviews.csv")
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
# Print out any information you need to understand your dataframe
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %% [markdown]
# ## Missing Data
#
# Try out different methods to locate and resolve missing data.

# %%
# Try to find some missing data!

#column
df.isnull().sum()

#percentage
(df.isnull().mean() * 100).round(2)

#rows
df[df.isnull().any(axis=1)].head()
# Out:
#     Unnamed: 0  Clothing ID  Age Title  \
# 0            0          767   33   NaN
# 1            1         1080   34   NaN
# 11          11         1095   39   NaN
# 30          30         1060   33   NaN
# 36          36         1002   29   NaN
#
#                                           Review Text  Rating  \
# 0   Absolutely wonderful - silky and sexy and comf...       4
# 1   Love this dress!  it's sooo pretty.  i happene...       5
# 11  This dress is perfection! so pretty and flatte...       5
# 30  Beautifully made pants and on trend with the f...       5
# 36  This is a comfortable skirt that can span seas...       4
#
#     Recommended IND  Positive Feedback Count   Division Name Department Name  \
# 0                 1                        0       Initmates        Intimate
# 1                 1                        4         General         Dresses
# 11                1                        2  General Petite         Dresses
# 30                1                        0  General Petite         Bottoms
# 36                1                        5         General         Bottoms
#
#    Class Name
# 0   Intimates
# 1     Dresses
# 11    Dresses
# 30      Pants
# 36     Skirts

# %% [markdown]
# Did you find any missing data? What things worked well for you and what did not?

# %%
# Respond to the above questions here:

#I found missing data in the "title" column which show NaN values. 
#Im not able to view the other columns and rows to see if any other data is missing

# %% [markdown]
# ## Irregular Data
#
# With missing data out of the way, turn your attention to any outliers. Just as we did for missing data, we first need to detect the outliers.

# %%
# Keep an eye out for outliers!

df.describe()
df.sort_values('Age', ascending=False).head()
df.sort_values('Positive Feedback Count', ascending=False).head()
df.sort_values('Age').head()
# Out:
#        Unnamed: 0  Clothing ID  Age                              Title  \
# 8858         8858         1094   18                               Love
# 22364       22364         1072   18          I get so many compliments
# 22390       22390          868   18  A little big, but so comfortable!
# 19704       19704         1008   18                           Stunning
# 8308         8308          868   19                     Super cute top
#
#                                              Review Text  Rating  \
# 8858   I bought this dress for my engagement photo sh...       5
# 22364  I found this dress on sale in store and i usua...       4
# 22390  This shirt is incredibly comfortable. the mate...       4
# 19704  This skirt is absolutely beautiful and is a go...       5
# 8308   I really love the style of this top. it's a gr...       4
#
#        Recommended IND  Positive Feedback Count Division Name Department Name  \
# 8858                 1                        0       General         Dresses
# 22364                1                        0       General         Dresses
# 22390                1                        0       General            Tops
# 19704                1                        1       General         Bottoms
# 8308                 1                        3       General            Tops
#
#       Class Name
# 8858     Dresses
# 22364    Dresses
# 22390      Knits
# 19704     Skirts
# 8308       Knits

# %% [markdown]
# What techniques helped you find outliers? In your opinion, what about the techniques you used made them effective?

# %%
# Make your notes here:

#I used the statistical and sorting techniques to look at min, max and quartile ranges in the numeric column.
#This allowed me to see what values are high or low, unnecessarily. I also sorted values in the age and 
#positive feedback court columns looking for outliers as well.

# %% [markdown]
# ## Unnecessary Data
#
# Unnecessary data could be irrelevant to your analysis or a duplicate column. Check out the dataset to see if there is any unnecessary data.

# %%
# Look out for unnecessary data!

df.columns
df.nunique()
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %% [markdown]
# Did you find any unnecessary data in your dataset? How did you handle it?

# %%
# Make your notes here.

#The "unnamed" column doesnt seem necessary becuase it does not give any valuable information about the 
#customer. With that said, I would just remove the column

# %% [markdown]
# ## Inconsistent Data
#
# Inconsistent data is likely due to inconsistent formatting and can be addressed by re-formatting all values in a column or row.

# %%
# Look out for inconsistent data!

df['Division Name'].unique()
df['Department Name'].unique()
df['Class Name'].unique()
# Out:
# array(['Intimates', 'Dresses', 'Pants', 'Blouses', 'Knits', 'Outerwear',
#        'Lounge', 'Sweaters', 'Skirts', 'Fine gauge', 'Sleep', 'Jackets',
#        'Swim', 'Trend', 'Jeans', 'Legwear', 'Shorts', 'Layering',
#        'Casual bottoms', nan, 'Chemises'], dtype=object)

# %% [markdown]
# Did you find any inconsistent data? What did you do to clean it?

# %%
# Make your notes here!

#I noticed that "Fine gauge & Cascual bottoms" does not have a Capitol letter in the second word
#There is also a "nan" value applying miss data
